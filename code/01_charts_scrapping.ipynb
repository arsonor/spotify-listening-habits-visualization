# %%
import random
from time import sleep
import requests as rq
import pandas as pd
import json
from datetime import datetime, timedelta, date

# %%
current_date = date(2022, 5, 12)
for _ in range(63):
    print(f'https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/{str(current_date)}')
    current_date -= timedelta(7)
# Out:
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-05-12
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-05-05
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-04-28
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-04-21
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-04-14
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-04-07
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-03-31
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-03-24
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-03-17
# https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2022-03-10
# ...

# %%
token = "Bearer BQBm2C7MvU58q9SksRQdzQOHxNzn8FsapWm1G9gdsOKZNpw8XzVu1RU9zzxlsINf8vcWC1t2OWGyw_xo19X9EArtWsvLLocvX5s43lPbk7GYlEx8ac3K3WoVSU6err6hOpAx80DuXvJPHaVwG80IBTFT2tYlbHGF1l6nfQX-9a3ha8EFfbso3j_1mQo0GDiKdDQqCF5TNLfxZJnSW7AJS6sx"
agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0'
# url = 'https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2024-02-22'

current_date = date(2024, 2, 22)
for i in range(156):
    url = f'https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-jp-weekly/{str(current_date)}'
    
    with rq.Session() as s:
        s.headers = {
            'authorization': token,
            'User-Agent': agent
        }

        r = s.get(url)
        print(r.status_code)
        data = r.json()
        sleep(random.randint(2,5))

    df = pd.json_normalize(data.get('entries'))
    artist_meta = pd.json_normalize(pd.json_normalize(df['trackMetadata.artists'])[0])
    df = pd.concat([df, artist_meta], axis=1)
    df['week'] = current_date

    if i == 0:
        df.to_csv('Japan_charts.csv', mode = 'w', index=False)
    else:
        df.to_csv('Japan_charts.csv', mode = 'a', header=False, index=False)

    current_date -= timedelta(7)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
token = "Bearer BQDtej_YNu0l9VoVOUuk1oc2vwxO-6RH6WSFsw4ShuUebhamKDKsP0x2sEcikjSqGYrDBL7MVsESeGMM3VR02BrLdhaqkduMMZ8994k6mI7EhfDL97MN_DL4MlAJjhSPZ6JRNQgXAPMRaLwKfRyZriEOhkWNIVlUMGOZKpJ4eaw5esTAMxvO6p1cjuDieGe7cEES4Gb4cd-iMGVlaAgsUtqz"
agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0'
# url = 'https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-global-weekly/2024-02-22'

current_date = date(2022, 9, 29)
for i in range(83):
    url = f'https://charts-spotify-com-service.spotify.com/auth/v0/charts/regional-tr-weekly/{str(current_date)}'
    
    with rq.Session() as s:
        s.headers = {
            'authorization': token,
            'User-Agent': agent
        }

        r = s.get(url)
        print(r.status_code)
        data = r.json()
        sleep(random.randint(5,10))

    df = pd.json_normalize(data.get('entries'))
    artist_meta = pd.json_normalize(pd.json_normalize(df['trackMetadata.artists'])[0])
    df = pd.concat([df, artist_meta], axis=1)
    df['week'] = current_date

    df.to_csv('Turkey_charts.csv', mode = 'a', header=False, index=False)

    current_date -= timedelta(7)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
pd.read_csv('Japan_charts.csv')
# Out:
#        missingRequiredFields  chartEntryData.currentRank  \
# 0                      False                           1
# 1                      False                           2
# 2                      False                           3
# 3                      False                           4
# 4                      False                           5
# ...                      ...                         ...
# 31195                  False                         196
# 31196                  False                         197
# 31197                  False                         198
# 31198                  False                         199
# 31199                  False                         200
#
#        chartEntryData.previousRank  chartEntryData.peakRank  \
# 0                                1                        1
# 1                                2                        2
# 2                                3                        1
# ...
